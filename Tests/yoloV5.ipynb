# %%
import cv2
import torch
from PIL import Image

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to /root/.cache/torch/hub/master.zip
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv5, attempting auto-update...
# Collecting PyYAML>=5.3.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
# Installing collected packages: PyYAML
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-6.0
#
# requirements: 1 package updated per /root/.cache/torch/hub/ultralytics_yolov5_master/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
# YOLOv5 🚀 2021-11-7 torch 1.9.0+cu111 CPU
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.0/yolov5s.pt to /root/.cache/torch/hub/ultralytics_yolov5_master/yolov5s.pt...
#   0%|          | 0.00/14.0M [00:00<?, ?B/s]
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
capture = cv2.VideoCapture('swing.mp4')
frameNr = 0
while (True):
    success, frame = capture.read() 
    if success:
        # Inference

        results = model(frame, size=640)  # includes NMS
        # Results
        results.print()  
        results.save()  # or .show()
    else:
        break
    frameNr = frameNr+1
capture.release()
# Out:
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 25.7ms pre-process, 379.0ms inference, 15.2ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 8.4ms pre-process, 248.4ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp2
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 6.7ms pre-process, 271.2ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp3
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 8.2ms pre-process, 246.5ms inference, 0.9ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp4
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 7.4ms pre-process, 237.1ms inference, 0.9ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp5
# image 1/1: 1552x970 1 person, 1 sports ball, 1 tennis racket
# Speed: 10.9ms pre-process, 258.2ms inference, 1.2ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp6
# image 1/1: 1552x970 1 person, 1 sports ball, 1 tennis racket
# Speed: 7.8ms pre-process, 251.1ms inference, 1.3ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp7
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 8.5ms pre-process, 257.0ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp8
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 9.8ms pre-process, 251.8ms inference, 0.9ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp9
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 8.5ms pre-process, 248.4ms inference, 1.2ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp10
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 5.7ms pre-process, 244.7ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp11
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 8.9ms pre-process, 260.5ms inference, 1.2ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp12
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 6.0ms pre-process, 245.2ms inference, 1.2ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp13
# image 1/1: 1552x970 1 person, 1 sports ball, 1 tennis racket
# Speed: 9.1ms pre-process, 249.8ms inference, 1.2ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp14
# image 1/1: 1552x970 1 person, 1 sports ball, 1 tennis racket
# Speed: 7.3ms pre-process, 254.5ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp15
# image 1/1: 1552x970 1 person, 1 sports ball, 1 tennis racket
# Speed: 8.5ms pre-process, 244.8ms inference, 0.9ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp16
# image 1/1: 1552x970 1 person, 1 sports ball, 1 tennis racket
# Speed: 6.9ms pre-process, 243.4ms inference, 1.5ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp17
# image 1/1: 1552x970 1 person, 1 sports ball, 1 tennis racket
# Speed: 9.1ms pre-process, 260.7ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp18
# image 1/1: 1552x970 1 person, 1 sports ball, 1 tennis racket
# Speed: 5.7ms pre-process, 245.7ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp19
# image 1/1: 1552x970 1 person, 2 sports balls, 1 tennis racket
# Speed: 8.7ms pre-process, 248.6ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp20
# image 1/1: 1552x970 1 person, 1 sports ball, 1 tennis racket
# Speed: 7.8ms pre-process, 249.9ms inference, 1.2ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp21
# image 1/1: 1552x970 1 person, 1 sports ball, 1 tennis racket
# Speed: 8.2ms pre-process, 251.1ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp22
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 10.1ms pre-process, 258.0ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp23
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 9.0ms pre-process, 267.2ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp24
# image 1/1: 1552x970 1 person, 1 sports ball, 1 tennis racket
# Speed: 8.5ms pre-process, 240.8ms inference, 0.9ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp25
# image 1/1: 1552x970 1 person, 1 sports ball, 1 tennis racket
# Speed: 8.4ms pre-process, 251.3ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp26
# image 1/1: 1552x970 1 person, 1 sports ball, 1 tennis racket
# Speed: 5.6ms pre-process, 247.1ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp27
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 8.4ms pre-process, 259.0ms inference, 0.9ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp28
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 9.4ms pre-process, 255.8ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp29
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 10.8ms pre-process, 259.5ms inference, 1.8ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp30
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 8.3ms pre-process, 242.5ms inference, 0.9ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp31
# image 1/1: 1552x970 1 person, 1 sports ball, 1 baseball bat
# Speed: 7.1ms pre-process, 239.1ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp32
# image 1/1: 1552x970 1 person, 1 sports ball, 1 baseball bat
# Speed: 8.7ms pre-process, 262.5ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp33
# image 1/1: 1552x970 1 person, 1 sports ball, 1 baseball bat
# Speed: 5.4ms pre-process, 253.0ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp34
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 8.5ms pre-process, 266.9ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp35
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 8.3ms pre-process, 272.2ms inference, 1.4ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp36
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 10.4ms pre-process, 268.2ms inference, 1.4ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp37
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 7.4ms pre-process, 247.5ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp38
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 9.2ms pre-process, 266.5ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp39
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 8.3ms pre-process, 244.4ms inference, 1.2ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp40
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 8.5ms pre-process, 288.8ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp41
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 8.6ms pre-process, 263.3ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp42
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 8.1ms pre-process, 261.0ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp43
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 7.2ms pre-process, 257.3ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp44
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 8.7ms pre-process, 253.5ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp45
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 5.6ms pre-process, 245.2ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp46
# image 1/1: 1552x970 1 person, 1 sports ball, 1 baseball bat
# Speed: 8.8ms pre-process, 281.5ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp47
# image 1/1: 1552x970 1 person, 1 sports ball, 1 baseball bat
# Speed: 8.7ms pre-process, 240.9ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp48
# image 1/1: 1552x970 1 person, 1 sports ball, 1 baseball bat
# Speed: 8.7ms pre-process, 257.4ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp49
# image 1/1: 1552x970 1 person, 1 sports ball, 1 baseball bat
# Speed: 6.1ms pre-process, 270.5ms inference, 1.3ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp50
# image 1/1: 1552x970 1 person, 1 sports ball, 1 baseball bat
# Speed: 8.8ms pre-process, 264.6ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp51
# image 1/1: 1552x970 1 person, 1 sports ball, 1 baseball bat
# Speed: 5.6ms pre-process, 259.8ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp52
# image 1/1: 1552x970 1 person, 1 sports ball, 1 baseball bat
# Speed: 8.7ms pre-process, 276.1ms inference, 1.3ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp53
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 8.8ms pre-process, 256.0ms inference, 1.4ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp54
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 8.8ms pre-process, 261.9ms inference, 1.2ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp55
# image 1/1: 1552x970 1 person, 1 frisbee, 1 sports ball
# Speed: 8.5ms pre-process, 256.1ms inference, 1.8ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp56
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 9.3ms pre-process, 277.9ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp57
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 8.8ms pre-process, 258.3ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp58
# image 1/1: 1552x970 1 person, 2 sports balls
# Speed: 8.8ms pre-process, 251.1ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp59
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 8.4ms pre-process, 250.4ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp60
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 9.5ms pre-process, 265.4ms inference, 1.3ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp61
# image 1/1: 1552x970 1 person
# Speed: 5.8ms pre-process, 254.4ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp62
# image 1/1: 1552x970 1 person
# Speed: 9.0ms pre-process, 261.4ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp63
# image 1/1: 1552x970 1 person
# Speed: 8.5ms pre-process, 270.8ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp64
# image 1/1: 1552x970 1 person, 1 tennis racket
# Speed: 8.9ms pre-process, 255.2ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp65
# image 1/1: 1552x970 1 person, 1 tennis racket
# Speed: 9.2ms pre-process, 254.7ms inference, 1.2ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp66
# image 1/1: 1552x970 1 person, 1 tennis racket
# Speed: 9.4ms pre-process, 274.2ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp67
# image 1/1: 1552x970 1 person
# Speed: 8.8ms pre-process, 250.9ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp68
# image 1/1: 1552x970 1 person
# Speed: 9.1ms pre-process, 264.8ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp69
# image 1/1: 1552x970 1 person
# Speed: 11.8ms pre-process, 267.7ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp70
# image 1/1: 1552x970 1 person
# Speed: 9.0ms pre-process, 250.6ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp71
# image 1/1: 1552x970 1 person, 1 sports ball
# Speed: 9.2ms pre-process, 256.1ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp72
# image 1/1: 1552x970 1 person, 1 tennis racket
# Speed: 8.8ms pre-process, 266.4ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp73
# image 1/1: 1552x970 1 person
# Speed: 5.7ms pre-process, 249.0ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp74
# image 1/1: 1552x970 1 person
# Speed: 9.3ms pre-process, 267.4ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp75
# image 1/1: 1552x970 1 person, 1 tennis racket
# Speed: 8.5ms pre-process, 262.0ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp76
# image 1/1: 1552x970 1 person
# Speed: 9.2ms pre-process, 262.2ms inference, 1.3ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp77
# image 1/1: 1552x970 1 person
# Speed: 8.7ms pre-process, 263.8ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp78
# image 1/1: 1552x970 1 person
# Speed: 9.6ms pre-process, 267.4ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp79
# image 1/1: 1552x970 1 person
# Speed: 8.4ms pre-process, 265.4ms inference, 1.3ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp80
# image 1/1: 1552x970 1 person
# Speed: 8.9ms pre-process, 262.7ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp81
# image 1/1: 1552x970 1 person
# Speed: 8.1ms pre-process, 247.4ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp82
# image 1/1: 1552x970 1 person
# Speed: 9.0ms pre-process, 261.0ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp83
# image 1/1: 1552x970 1 person
# Speed: 6.9ms pre-process, 256.6ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp84
# image 1/1: 1552x970 1 person
# Speed: 8.8ms pre-process, 254.9ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp85
# image 1/1: 1552x970 1 person
# Speed: 8.3ms pre-process, 259.6ms inference, 1.7ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp86
# image 1/1: 1552x970 1 person
# Speed: 8.7ms pre-process, 281.4ms inference, 1.5ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp87
# image 1/1: 1552x970 1 person
# Speed: 5.8ms pre-process, 245.9ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp88
# image 1/1: 1552x970 1 person
# Speed: 9.5ms pre-process, 262.5ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp89
# image 1/1: 1552x970 1 person
# Speed: 8.4ms pre-process, 266.8ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp90
# image 1/1: 1552x970 1 person
# Speed: 8.6ms pre-process, 250.2ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp91
# image 1/1: 1552x970 1 person, 1 frisbee
# Speed: 8.1ms pre-process, 254.6ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp92
# image 1/1: 1552x970 1 person, 1 frisbee
# Speed: 8.6ms pre-process, 284.5ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp93
# image 1/1: 1552x970 1 person
# Speed: 8.6ms pre-process, 251.5ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp94
# image 1/1: 1552x970 1 person, 1 frisbee
# Speed: 8.9ms pre-process, 273.0ms inference, 1.4ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp95
# image 1/1: 1552x970 1 person, 1 frisbee, 1 baseball bat, 1 tennis racket
# Speed: 6.3ms pre-process, 272.1ms inference, 1.3ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp96
# image 1/1: 1552x970 1 person, 1 frisbee, 1 baseball bat, 1 tennis racket
# Speed: 9.1ms pre-process, 264.6ms inference, 1.2ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp97
# image 1/1: 1552x970 1 person, 1 frisbee, 1 tennis racket
# Speed: 5.8ms pre-process, 262.2ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp98
# image 1/1: 1552x970 1 person, 1 frisbee
# Speed: 9.3ms pre-process, 273.9ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp99
# image 1/1: 1552x970 1 person, 1 frisbee
# Speed: 5.8ms pre-process, 255.3ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp100
# image 1/1: 1552x970 1 person, 1 frisbee
# Speed: 8.9ms pre-process, 264.3ms inference, 1.1ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp101
# image 1/1: 1552x970 1 person, 1 frisbee, 1 baseball bat
# Speed: 8.4ms pre-process, 255.8ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp102
# image 1/1: 1552x970 1 person, 1 frisbee, 1 baseball bat
# Speed: 8.5ms pre-process, 257.2ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp103
# image 1/1: 1552x970 1 person, 1 frisbee, 1 baseball bat
# Speed: 5.7ms pre-process, 246.3ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp104
# image 1/1: 1552x970 1 person, 1 frisbee, 1 baseball bat
# Speed: 5.7ms pre-process, 252.0ms inference, 1.0ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp105
# image 1/1: 1552x970 1 person, 1 frisbee, 1 baseball bat
# Speed: 5.5ms pre-process, 259.1ms inference, 1.4ms NMS per image at shape (1, 3, 640, 416)
# Saved 1 image to runs/detect/exp106

# %%
from google.colab.patches import cv2_imshow
results.display(render=True)
cv2_imshow(results.imgs[0])
# Out:
# <PIL.Image.Image image mode=RGB size=970x1552 at 0x7F60B23716D0>

# %%
results.xyxy[0]  # img1 predictions (tensor)
results.pandas().xyxy[0]  # img1 predictions (pandas)
# Out:
#          xmin         ymin        xmax         ymax  confidence  class  \
# 0  342.370117   146.713211  719.449890  1302.599976    0.905236      0
# 1  479.069977   190.017014  596.631653   431.797760    0.581989     34
# 2  312.779297  1138.201416  397.596649  1319.873169    0.371636     29
#
#            name
# 0        person
# 1  baseball bat
# 2       frisbee
